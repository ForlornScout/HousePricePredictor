# %%
import pandas as pd

# %%
featuresRequired = {'BedroomAbvGr': 1, 'FullBath': 1, 'HalfBath': 1}

# %%
data = pd.read_csv('Dataset/train.csv')
data['MatchRating'] = 0
# for index in data.index:
#     if data.loc[index,'Id'] == 2:
#         data.loc[index, 'MatchRating'] = 1000

for index in data.index:
    for key in featuresRequired:
        if data.loc[index,key] == featuresRequired[key]:
            data.loc[index,'MatchRating'] = data.loc[index,'MatchRating']+1

# %%
data = data[data.MatchRating > 0]
data.sort_values(by=['MatchRating'], inplace=True, ascending=False)
data = data.head(5)
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 46      47          50       RL         48.0    12822   Pave   NaN      IR1
# 977    978         120       FV         35.0     4274   Pave  Pave      IR1
# 1093  1094          20       RL         71.0     9230   Pave   NaN      Reg
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 400    401         120       RL         38.0    14963   Pave   NaN      IR2
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 46           Lvl    AllPub  ...    NaN    NaN         NaN       0      8
# 977          Lvl    AllPub  ...    NaN    NaN         NaN       0     11
# 1093         Lvl    AllPub  ...    NaN  MnPrv         NaN       0     10
# 5            Lvl    AllPub  ...    NaN  MnPrv        Shed     700     10
# 400          Lvl    AllPub  ...    NaN    NaN         NaN       0     12
#
#      YrSold SaleType  SaleCondition  SalePrice  MatchRating
# 46     2009       WD        Abnorml     239686            3
# 977    2007      New        Partial     199900            3
# 1093   2006       WD         Normal     146000            3
# 5      2009       WD         Normal     143000            3
# 400    2008       WD         Normal     245500            3
#
# [5 rows x 82 columns]

# %%
data.to_json(orient="records")
# Out:
# '[{"Id":47,"MSSubClass":50,"MSZoning":"RL","LotFrontage":48.0,"LotArea":12822,"Street":"Pave","Alley":null,"LotShape":"IR1","LandContour":"Lvl","Utilities":"AllPub","LotConfig":"CulDSac","LandSlope":"Gtl","Neighborhood":"Mitchel","Condition1":"Norm","Condition2":"Norm","BldgType":"1Fam","HouseStyle":"1.5Fin","OverallQual":7,"OverallCond":5,"YearBuilt":2003,"YearRemodAdd":2003,"RoofStyle":"Gable","RoofMatl":"CompShg","Exterior1st":"VinylSd","Exterior2nd":"VinylSd","MasVnrType":"None","MasVnrArea":0.0,"ExterQual":"Gd","ExterCond":"TA","Foundation":"PConc","BsmtQual":"Ex","BsmtCond":"TA","BsmtExposure":"No","BsmtFinType1":"GLQ","BsmtFinSF1":1351,"BsmtFinType2":"Unf","BsmtFinSF2":0,"BsmtUnfSF":83,"TotalBsmtSF":1434,"Heating":"GasA","HeatingQC":"Ex","CentralAir":"Y","Electrical":"SBrkr","1stFlrSF":1518,"2ndFlrSF":631,"LowQualFinSF":0,"GrLivArea":2149,"BsmtFullBath":1,"BsmtHalfBath":0,"FullBath":1,"HalfBath":1,"BedroomAbvGr":1,"KitchenAbvGr":1,"KitchenQual":"Gd","TotRmsAbvGrd":6,"Functional":"Typ","Fireplaces":1,"FireplaceQu":"Ex","GarageType":"Attchd","GarageYrBlt":2003.0,"GarageFinish":"RFn","GarageCars":2,"GarageArea":670,"GarageQual":"TA","GarageCond":"TA","PavedDrive":"Y","WoodDeckSF":168,"OpenPorchSF":43,"EnclosedPorch":0,"3SsnPorch":0,"ScreenPorch":198,"PoolArea":0,"PoolQC":null,"Fence":null,"MiscFeature":null,"MiscVal":0,"MoSold":8,"YrSold":2009,"SaleType":"WD","SaleCondition":"Abnorml","SalePrice":239686,"MatchRating":3},{"Id":978,"MSSubClass":120,"MSZoning":"FV","LotFrontage":35.0,"LotArea":4274,"Street":"Pave","Alley":"Pave","LotShape":"IR1","LandContour":"Lvl","Utilities":"AllPub","LotConfig":"Inside","LandSlope":"Gtl","Neighborhood":"Somerst","Condition1":"Norm","Condition2":"Norm","BldgType":"TwnhsE","HouseStyle":"1Story","OverallQual":7,"OverallCond":5,"YearBuilt":2006,"YearRemodAdd":2007,"RoofStyle":"Gable","RoofMatl":"CompShg","Exterior1st":"VinylSd","Exterior2nd":"VinylSd","MasVnrType":null,"MasVnrArea":null,"ExterQual":"Gd","ExterCond":"TA","Foundation":"PConc","BsmtQual":"Gd","BsmtCond":"TA","BsmtExposure":"No","BsmtFinType1":"GLQ","BsmtFinSF1":1106,"BsmtFinType2":"Unf","BsmtFinSF2":0,"BsmtUnfSF":135,"TotalBsmtSF":1241,"Heating":"GasA","HeatingQC":"Ex","CentralAir":"Y","Electrical":"SBrkr","1stFlrSF":1241,"2ndFlrSF":0,"LowQualFinSF":0,"GrLivArea":1241,"BsmtFullBath":1,"BsmtHalfBath":0,"FullBath":1,"HalfBath":1,"BedroomAbvGr":1,"KitchenAbvGr":1,"KitchenQual":"Gd","TotRmsAbvGrd":4,"Functional":"Typ","Fireplaces":0,"FireplaceQu":null,"GarageType":"Attchd","GarageYrBlt":2007.0,"GarageFinish":"Fin","GarageCars":2,"GarageArea":569,"GarageQual":"TA","GarageCond":"TA","PavedDrive":"Y","WoodDeckSF":0,"OpenPorchSF":116,"EnclosedPorch":0,"3SsnPorch":0,"ScreenPorch":0,"PoolArea":0,"PoolQC":null,"Fence":null,"MiscFeature":null,"MiscVal":0,"MoSold":11,"YrSold":2007,"SaleType":"New","SaleCondition":"Partial","SalePrice":199900,"MatchRating":3},{"Id":1094,"MSSubClass":20,"MSZoning":"RL","LotFrontage":71.0,"LotArea":9230,"Street":"Pave","Alley":null,"LotShape":"Reg","LandContour":"Lvl","Utilities":"AllPub","LotConfig":"Corner","LandSlope":"Gtl","Neighborhood":"NAmes","Condition1":"Feedr","Condition2":"Norm","BldgType":"1Fam","HouseStyle":"1Story","OverallQual":5,"OverallCond":8,"YearBuilt":1965,"YearRemodAdd":1998,"RoofStyle":"Hip","RoofMatl":"CompShg","Exterior1st":"MetalSd","Exterior2nd":"MetalSd","MasVnrType":"BrkFace","MasVnrArea":166.0,"ExterQual":"TA","ExterCond":"TA","Foundation":"CBlock","BsmtQual":"TA","BsmtCond":"TA","BsmtExposure":"Mn","BsmtFinType1":"GLQ","BsmtFinSF1":661,"BsmtFinType2":"Unf","BsmtFinSF2":0,"BsmtUnfSF":203,"TotalBsmtSF":864,"Heating":"GasA","HeatingQC":"Gd","CentralAir":"Y","Electrical":"SBrkr","1stFlrSF":1200,"2ndFlrSF":0,"LowQualFinSF":0,"GrLivArea":1200,"BsmtFullBath":1,"BsmtHalfBath":0,"FullBath":1,"HalfBath":1,"BedroomAbvGr":1,"KitchenAbvGr":1,"KitchenQual":"Gd","TotRmsAbvGrd":6,"Functional":"Typ","Fireplaces":0,"FireplaceQu":null,"GarageType":"Detchd","GarageYrBlt":1977.0,"GarageFinish":"Unf","G ...
